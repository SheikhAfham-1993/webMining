# %%
# Out:
# downloading train_5500.label
# C:\UNI_Mannheim\4th_Semi\WM\webMining\Notebook\.data\trec\train_5500.label: 100%|████| 336k/336k [00:00<00:00, 710kB/s]
# downloading TREC_10.label
# C:\UNI_Mannheim\4th_Semi\WM\webMining\Notebook\.data\trec\TREC_10.label: 100%|█████| 23.4k/23.4k [00:00<00:00, 198kB/s]

# %%
#df_emotions = pd.read_csv('../Datasets/train/text_emotion.csv')

# %%
data
# Out:
# <module 'torchtext.legacy.data' from 'C:\\Users\\sh_af\\AppData\\Roaming\\Python\\Python37\\site-packages\\torchtext\\legacy\\data\\__init__.py'>

# %%
data[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-c402bf503b75> in <module>
# ----> 1 data[1]
#
# TypeError: 'module' object is not subscriptable

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-ab0a5b0d7958> in <module>
# ----> 1 data.dtype
#
# AttributeError: module 'torchtext.legacy.data' has no attribute 'dtype'
