# %%
import pandas as pd

# %%
df = pd.read_csv('../Datasets/labeled_dataset/train_lonora.csv',header=None, encoding = 'ISO-8859-1')

# %%
df_sub=df.iloc[751:1001, :]

# %%
df_sub.to_csv('../Datasets/labeled_dataset/train_lonora.csv')
