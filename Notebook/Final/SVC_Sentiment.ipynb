# %%
import pandas as pd
import numpy as np
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import accuracy_score,precision_score,recall_score
from sklearn.svm import SVC

# %%
nlp = spacy.load('en_core_web_lg')

# %%
df = pd.read_csv('../Datasets/train/steam_ds.csv')

# %%
df.head()
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review user_suggestion
# 0  I'm scared and hearing creepy voices.  So I'll...        Positive
# 1  Best game, more better than Sam Pepper's YouTu...        Positive
# 2  A littly iffy on the controls, but once you kn...        Positive
# 3  Great game, fun and colorful and all that.A si...        Positive
# 4  Not many games have the cute tag right next to...        Positive

# %%
df['user_review'] = df['user_review'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df.head()
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review user_suggestion
# 0  i'm scared and hearing creepy voices. so i'll ...        Positive
# 1  best game, more better than sam pepper's youtu...        Positive
# 2  a littly iffy on the controls, but once you kn...        Positive
# 3  great game, fun and colorful and all that.a si...        Positive
# 4  not many games have the cute tag right next to...        Positive

# %%
df['user_review'] = df['user_review'].str.replace('[^\w\s]','')
df.head()
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review user_suggestion
# 0  im scared and hearing creepy voices so ill pau...        Positive
# 1  best game more better than sam peppers youtube...        Positive
# 2  a littly iffy on the controls but once you kno...        Positive
# 3  great game fun and colorful and all thata side...        Positive
# 4  not many games have the cute tag right next to...        Positive

# %%
stop = stopwords.words('english')
df['user_review'] = df['user_review'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df.head()
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review user_suggestion
# 0  im scared hearing creepy voices ill pause mome...        Positive
# 1  best game better sam peppers youtube account 1...        Positive
# 2  littly iffy controls know play easy master ive...        Positive
# 3  great game fun colorful thata side note though...        Positive
# 4  many games cute tag right next horror tag stea...        Positive

# %%
labels = df[['user_suggestion']]
text = df[['user_review']]

# %%
#X_train, x_test, Y_train,Y_test  = train_test_split(text, labels, test_size = 0.15, random_state=42)

# %%
def space(comment):
    doc = nlp(comment)
    return " ".join([token.lemma_ for token in doc])
df['user_review']= df['user_review'].apply(space)
df.head()
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review user_suggestion
# 0  -PRON- be scare hear creepy voice ill pause mo...        Positive
# 1  good game well sam peppers youtube account 101...        Positive
# 2  littly iffy control know play easy master -PRO...        Positive
# 3  great game fun colorful thata side note though...        Positive
# 4  many game cute tag right next horror tag steam...        Positive

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()
df['user_suggestion'] = le.fit_transform(df['user_suggestion'])
df.head(100)
# Out:
#     review_id                        title    year  \
# 0           1  Spooky's Jump Scare Mansion  2016.0
# 1           2  Spooky's Jump Scare Mansion  2016.0
# 2           3  Spooky's Jump Scare Mansion  2016.0
# 3           4  Spooky's Jump Scare Mansion  2015.0
# 4           5  Spooky's Jump Scare Mansion  2015.0
# ..        ...                          ...     ...
# 95         96  Spooky's Jump Scare Mansion  2015.0
# 96         97  Spooky's Jump Scare Mansion  2015.0
# 97         98  Spooky's Jump Scare Mansion  2015.0
# 98         99  Spooky's Jump Scare Mansion  2018.0
# 99        100  Spooky's Jump Scare Mansion  2015.0
#
#                                           user_review  user_suggestion
# 0   -PRON- be scare hear creepy voice ill pause mo...                1
# 1   good game well sam peppers youtube account 101...                1
# 2   littly iffy control know play easy master -PRO...                1
# 3   great game fun colorful thata side note though...                1
# 4   many game cute tag right next horror tag steam...                1
# ..                                                ...              ...
# 95  early access reviewi love game -PRON- be curre...                1
# 96  wander 10 room without see anything get startl...                1
# 97  early access reviewthe game start cute jump sc...                1
# 98  pretty obviously part seeminglynormalthencreep...                1
# 99  hell rubbish there s nothing go one door anoth...                0
#
# [100 rows x 5 columns]

# %%
from nltk.tokenize import RegexpTokenizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(stop_words='english',ngram_range = (1,1),tokenizer = token.tokenize)
text_counts = cv.fit_transform(df['user_review'])
X_train, X_test, Y_train, Y_test = train_test_split(text_counts,df['user_suggestion'] ,test_size=0.25, random_state=5)

# %%
svclassifier = SVC(kernel='sigmoid')
svclassifier.fit(X_train, Y_train)
#gnb.fit(data_train, target_train)
# Out:
# C:\Users\Arun Thapa\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='sigmoid', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
from sklearn import metrics

# %%
predicted = svclassifier.predict(X_test)
accuracy_score = metrics.accuracy_score(predicted, Y_test)
print(str('{:04.2f}'.format(accuracy_score*100))+'%')
# Out:
# 56.74%

# %%
recall = recall_score( Y_test, predicted, average='weighted')
print('Recall: %.3f' % recall)
# Out:
# Recall: 0.567
