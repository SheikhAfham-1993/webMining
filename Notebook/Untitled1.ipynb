# %%
import pandas as pd

# %%
df_orig = pd.read_csv('../Datasets/train/steam_ds.csv')
df_Afham = pd.read_csv('../Datasets/labeled_dataset/train_afham.csv')
df_Nora = pd.read_csv('../Datasets/labeled_dataset/train_lonora.csv')
df_Arun = pd.read_csv('../Datasets/labeled_dataset/train_arun.csv')
df_Farida = pd.read_csv('../Datasets/labeled_dataset/train_farida.csv')

# %%
df_Farida
# Out:
#      review_id                        title    year  \
# 0          251  Spooky's Jump Scare Mansion  2015.0
# 1          252  Spooky's Jump Scare Mansion  2017.0
# 2          253  Spooky's Jump Scare Mansion  2015.0
# 3          254  Spooky's Jump Scare Mansion  2015.0
# 4          255  Spooky's Jump Scare Mansion  2015.0
# ..         ...                          ...     ...
# 245        496               Sakura Clicker  2015.0
# 246        497               Sakura Clicker  2015.0
# 247        498               Sakura Clicker  2015.0
# 248        499               Sakura Clicker  2016.0
# 249        500               Sakura Clicker  2015.0
#
#                                            user_review  user_suggestion  \
# 0    Early Access ReviewSo, I was all like, "Aww, t...                1
# 1    Very fun and actually terrifying game.  Got in...                1
# 2    Early Access ReviewSo far, this has been an am...                1
# ...

# %%
#df_Arun.columns = ['review_id','title','year','user_review','user_suggestion','emotions']

# %%
df_comb = [df_Afham, df_Farida, df_Arun, df_Nora]

# %%
df_merged = pd.concat(df_comb)

# %%
df_merged.shape

# %%
df_merged.to_csv('../Datasets/labeled_dataset/test_merged.csv', index=False)
