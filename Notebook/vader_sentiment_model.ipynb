# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import re
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from wordcloud import WordCloud, STOPWORDS
import spacy
from sklearn import preprocessing
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import metrics
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
df = pd.read_csv('../Datasets/train/steam_ds.csv', encoding = "ISO-8859-1" )
df.head()
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review user_suggestion
# 0  I'm scared and hearing creepy voices.  So I'll...        Positive
# 1  Best game, more better than Sam Pepper's YouTu...        Positive
# 2  A littly iffy on the controls, but once you kn...        Positive
# 3  Great game, fun and colorful and all that.A si...        Positive
# 4  Not many games have the cute tag right next to...        Positive

# %%
sid = SentimentIntensityAnalyzer()

# %%
df['user_suggestion'].value_counts()
# Out:
# Positive    9968
# Negative    7526
# Name: user_suggestion, dtype: int64

# %%
df['scores'] = df['user_review'].apply(lambda review: sid.polarity_scores(review))
df.head()
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review user_suggestion  \
# 0  I'm scared and hearing creepy voices.  So I'll...        Positive
# 1  Best game, more better than Sam Pepper's YouTu...        Positive
# 2  A littly iffy on the controls, but once you kn...        Positive
# 3  Great game, fun and colorful and all that.A si...        Positive
# 4  Not many games have the cute tag right next to...        Positive
#
#                                               scores
# 0  {'neg': 0.121, 'neu': 0.774, 'pos': 0.106, 'co...
# 1  {'neg': 0.062, 'neu': 0.795, 'pos': 0.143, 'co...
# 2  {'neg': 0.0, 'neu': 0.662, 'pos': 0.338, 'comp...
# 3  {'neg': 0.1, 'neu': 0.672, 'pos': 0.228, 'comp...
# 4  {'neg': 0.046, 'neu': 0.741, 'pos': 0.213, 'co...

# %%
df['compound']  = df['scores'].apply(lambda score_dict: score_dict['compound'])
df.head()
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review user_suggestion  \
# 0  I'm scared and hearing creepy voices.  So I'll...        Positive
# 1  Best game, more better than Sam Pepper's YouTu...        Positive
# 2  A littly iffy on the controls, but once you kn...        Positive
# 3  Great game, fun and colorful and all that.A si...        Positive
# 4  Not many games have the cute tag right next to...        Positive
#
#                                               scores  compound
# 0  {'neg': 0.121, 'neu': 0.774, 'pos': 0.106, 'co...   -0.7431
# 1  {'neg': 0.062, 'neu': 0.795, 'pos': 0.143, 'co...    0.6361
# 2  {'neg': 0.0, 'neu': 0.662, 'pos': 0.338, 'comp...    0.9851
# 3  {'neg': 0.1, 'neu': 0.672, 'pos': 0.228, 'comp...    0.8146
# 4  {'neg': 0.046, 'neu': 0.741, 'pos': 0.213, 'co...    0.9107

# %%
df['comp_score'] = df['compound'].apply(lambda c: 'Positive' if c >=0 else 'Negative')

df.head()
# Out:
#    review_id                        title    year  \
# 0          1  Spooky's Jump Scare Mansion  2016.0
# 1          2  Spooky's Jump Scare Mansion  2016.0
# 2          3  Spooky's Jump Scare Mansion  2016.0
# 3          4  Spooky's Jump Scare Mansion  2015.0
# 4          5  Spooky's Jump Scare Mansion  2015.0
#
#                                          user_review user_suggestion  \
# 0  I'm scared and hearing creepy voices.  So I'll...        Positive
# 1  Best game, more better than Sam Pepper's YouTu...        Positive
# 2  A littly iffy on the controls, but once you kn...        Positive
# 3  Great game, fun and colorful and all that.A si...        Positive
# 4  Not many games have the cute tag right next to...        Positive
#
#                                               scores  compound comp_score
# 0  {'neg': 0.121, 'neu': 0.774, 'pos': 0.106, 'co...   -0.7431   Negative
# 1  {'neg': 0.062, 'neu': 0.795, 'pos': 0.143, 'co...    0.6361   Positive
# 2  {'neg': 0.0, 'neu': 0.662, 'pos': 0.338, 'comp...    0.9851   Positive
# 3  {'neg': 0.1, 'neu': 0.672, 'pos': 0.228, 'comp...    0.8146   Positive
# 4  {'neg': 0.046, 'neu': 0.741, 'pos': 0.213, 'co...    0.9107   Positive

# %%
accuracy_score = metrics.accuracy_score(df['user_suggestion'], df['comp_score'])
print(str('{:04.2f}'.format(accuracy_score*100))+'%')
# Out:
# 69.31%
